# %%
# Importar librerías a utilizar 
import numpy as np 
import matplotlib as plt 
import random

# %%
# Variables
# Longitud del cromosoma: 4
# Conjunto de elementos del cromosoma: {0,1}
# Número de individuos de la población: 2
# Para la creación de la primera generación:
# Probabilidad del elemento '0': número aleatorio < 0.5
# Probabilidad del elemento '1':  número aleatorio > 0.5
# Probabilidad de emparejamiento (crossover): 0.7
# Probabilidad de mutación: 0.3
Lcrom = 4
n_ind = 2
prob_0_1 = 0.5
prob_empar = 0.7
prob_mut = 0.3
pos_aleat = 0
prob1 = 0
prob2 = 0
max_fit = 0
max_gen = 0
max_x = 0
x1 = 0
x2 = 0
f1 = 0
f2 = 0
cromosoma1 = [0] * Lcrom
cromosoma2 = [0] * Lcrom
aux1 = cromosoma1
aux2 = cromosoma2

# %%
# lista números aleatorios
def listaAleatorios(n):
    lista = [0] * n
    for i in range(n):
        lista[i] = int(100*random.random())/100
    return lista

# %%
# Crear la lista aleatoria de números
n_aleat = 1000
lista = listaAleatorios(n_aleat)
print("lista aleatoria", lista)
# Out:
# lista aleatoria [0.45, 0.73, 0.31, 0.38, 0.88, 0.72, 0.33, 0.72, 0.04, 0.22, 0.73, 0.68, 0.03, 0.71, 0.6, 0.36, 0.52, 0.62, 0.6, 0.78, 0.42, 0.1, 0.54, 0.21, 0.71, 0.73, 0.67, 0.72, 0.82, 0.15, 0.41, 0.56, 0.69, 0.64, 0.3, 0.25, 0.76, 0.1, 0.21, 0.63, 0.87, 0.61, 0.18, 0.69, 0.44, 0.53, 0.82, 0.39, 0.12, 0.94, 0.23, 0.67, 0.72, 0.13, 0.56, 0.62, 0.54, 0.48, 0.99, 0.25, 0.54, 0.37, 0.77, 0.14, 0.03, 0.76, 0.37, 0.46, 0.21, 0.63, 0.89, 0.49, 0.65, 0.62, 0.87, 0.88, 0.97, 0.75, 0.52, 0.99, 0.02, 0.06, 0.71, 0.64, 0.75, 0.38, 0.59, 0.73, 0.24, 0.77, 0.23, 0.12, 0.36, 0.09, 0.08, 0.87, 0.76, 0.57, 0.47, 0.32, 0.84, 0.0, 0.6, 0.61, 0.85, 0.16, 0.29, 0.1, 0.18, 0.67, 0.35, 0.96, 0.74, 0.59, 0.43, 0.6, 0.43, 0.47, 0.53, 0.72, 0.27, 0.8, 0.0, 0.54, 0.9, 0.75, 0.06, 0.79, 0.97, 0.98, 0.61, 0.23, 0.61, 0.7, 0.44, 0.33, 0.27, 0.92, 0.6, 0.23, 0.63, 0.83, 0.08, 0.22, 0.53, 0.75, 0.32, 0.33, 0.65, 0.01, 0.9, 0.59, 0.76, 0.31, 0.26, 0.83, 0.4, 0.54, 0.87, 0.41, 0.12, 0.98, 0.27, 0.37, 0.33, 0.63, 0.84, 0.55, 0.24, 0.96, 0.34, 0.87, 0.65, 0.38, 0.65, 0.22, 0.6, 0.39, 0.16, 0.49, 0.07, 0.15, 0.59, 0.52, 0.74, 0.42, 0.67, 0.94, 0.93, 0.37, 0.08, 0.31, 0.77, 0.88, 0.78, 0.08, 0.39, 0.18, 0.19, 0.93, 0.56, 0.16, 0.83, 0.19, 0.71, 0.99, 0.57, 0.34, 0.08, 0.01, 0.9, 0.11, 0.25, 0.82, 0.14, 0.87, 0.57, 0.99, 0.01, 0.02, 0.71, 0.1, 0.51, 0.66, 0.95, 0.99, 0.15, 0.59, 0.59, 0.46, 0.69, 0.0, 0.31, 0.33, 0.58, 0.93, 0.41, 0.66, 0.17, 0.4, 0.67, 0.39, 0.85, 0.24, 0.22, 0.97, 0.51, 0.98, 0.47, 0.83, 0.88, 0.69, 0.74, 0.2, 0.02, 0.46, 0.29, 0.63, 0.11, 0.92, 0.84, 0.67, 0.83, 0.74, 0.47, 0.42, 0.81, 0.62, 0.32, 0.86, 0.53, 0.02, 0.29, 0.21, 0.42, 0.93, 0.71, 0.28, 0.12, 0.62, 0.77, 0.53, 0.13, 0.63, 0.34, 0.82, 0.93, 0.52, 0.63, 0.66, 0.49, 0.34, 0.46, 0.89, 0.55, 0.76, 0.68, 0.36, 0.52, 0.82, 0.34, 0.05, 0.83, 0.28, 0.19, 0.09, 0.64, 0.47, 0.16, 0.37, 0.53, 0.79, 0.06, 0.46, 0.06, 0.25, 0.44, 0.07, 0.43, 0.78, 0.36, 0.08, 0.06, 0.49, 0.89, 0.34, 0.58, 0.29, 0.19, 0.0, 0.61, 0.93, 0.8, 0.16, 0.16, 0.16, 0.68, 0.0, 0.95, 0.02, 0.55, 0.4, 0.27, 0.86, 0.29, 0.19, 0.1, 0.69, 0.04, 0.92, 0.65, 0.69, 0.23, 0.11, 0.35, 0.26, 0.54, 0.39, 0.4, 0.98, 0.11, 0.75, 0.13, 0.74, 0.72, 0.15, 0.38, 0.32, 0.05, 0.46, 0.07, 0.12, 0.0, 0.75, 0.92, 0.67, 0.71, 0.37, 0.73, 0.08, 0.26, 0.37, 0.03, 0.12, 0.62, 0.89, 0.92, 0.82, 0.48, 0.94, 0.23, 0.1, 0.37, 0.39, 0.04, 0.12, 0.73, 0.34, 0.03, 0.74, 0.09, 0.65, 0.1, 0.52, 0.39, 0.68, 0.91, 0.8, 0.7, 0.64, 0.33, 0.12, 0.81, 0.31, 0.91, 0.46, 0.87, 0.18, 0.27, 0.17, 0.41, 0.49, 0.02, 0.7, 0.81, 0.87, 0.37, 0.1, 0.31, 0.03, 0.42, 0.31, 0.79, 0.12, 0.74, 0.52, 0.66, 0.29, 0.98, 0.4, 0.47, 0.67, 0.06, 0.7, 0.19, 0.17, 0.61, 0.71, 0.19, 0.82, 0.74, 0.22, 0.37, 0.16, 0.78, 0.8, 0.94, 0.4, 0.33, 0.97, 0.87, 0.8, 0.76, 0.72, 0.83, 0.1, 0.18, 0.36, 0.95, 0.03, 0.83, 0.45, 0.28, 0.48, 0.4, 0.44, 0.22, 0.94, 0.6, 0.92, 0.94, 0.35, 0.09, 0.43, 0.66, 0.69, 0.3, 0.39, 0.71, 0.11, 0.18, 0.83, 0.96, 0.98, 0.09, 0.17, 0.64, 0.92, 0.15, 0.76, 0.02, 0.95, 0.71, 0.55, 0.69, 0.13, 0.01, 0.06, 0.02, 0.7, 0.33, 0.82, 0.5, 0.99, 0.26, 0.57, 0.89, 0.17, 0.88, 0.25, 0.22, 0.52, 0.12, 0.31, 0.18, 0.79, 0.71, 0.29, 0.92, 0.12, 0.21, 0.95, 0.42, 0.7, 0.35, 0.53, 0.82, 0.67, 0.74, 0.91, 0.96, 0.09, 0.7, 0.17, 0.17, 0.32, 0.21, 0.16, 0.45, 0.51, 0.86, 0.53, 0.25, 0.8, 0.45, 0.47, 0.23, 0.28, 0.87, 0.73, 0.32, 0.69, 0.3, 0.01, 0.84, 0.08, 0.25, 0.33, 0.41, 0.93, 0.82, 0.1, 0.37, 0.24, 0.03, 0.68, 0.65, 0.56, 0.38, 0.84, 0.88, 0.97, 0.84, 0.22, 0.36, 0.97, 0.57, 0.82, 0.91, 0.88, 0.27, 0.22, 0.54, 0.74, 0.05, 0.7, 0.39, 0.13, 0.59, 0.94, 0.8, 0.15, 0.56, 0.29, 0.7, 0.99, 0.96, 0.86, 0.68, 0.28, 0.73, 0.42, 0.03, 0.86, 0.59, 0.87, 0.05, 0.17, 0.35, 0.52, 0.86, 0.96, 0.29, 0.66, 0.98, 0.11, 0.26, 0.37, 0.19, 0.24, 0.78, 0.55, 0.94, 0.06, 0.43, 0.63, 0.32, 0.51, 0.02, 0.54, 0.4, 0.65, 0.93, 0.01, 0.09, 0.73, 0.22, 0.47, 0.59, 0.27, 0.72, 0.15, 0.09, 0.03, 0.44, 0.68, 0.96, 0.31, 0.0, 0.66, 0.0, 0.85, 0.89, 0.27, 0.88, 0.78, 0.67, 0.07, 0.6, 0.75, 0.19, 0.56, 0.71, 0.2 ...

# %%
def inicializarcromosomas(k):
    # Cromosomas iniciales
    print("GENERACIÓN INICIAL")
    # Individuo 1
    #cromosoma1 = [0]  * Lcrom
    j = 0
    for i in range(k, k+Lcrom):
        if lista[i] > prob_0_1:
            cromosoma1[j] = 1
        else:
            cromosoma1[j] = 0
        j = j+1

    k = k+Lcrom

    print("Individuo 1 :", cromosoma1)

    # Individuo 2
    #cromosoma2 = [0]  * Lcrom
    j = 0
    for i in range(k, k+Lcrom):
        if lista[i] > prob_0_1:
            cromosoma2[j] = 1
        else:
            cromosoma2[j] = 0
        j = j+1

    k = k+Lcrom

    print("Individuo 2 :", cromosoma2)

    return

# %%
# función de fitness
def fitness(x):
    y = np.abs((x-5)/(2+np.sin(x)))
    return y

# %%
def resultadofitness():
    # Fitness de individuos
    x1 = cromosoma1[3]*1+cromosoma1[2]*2+cromosoma1[1]*2*2+cromosoma1[0]*2*2*2
    x2 = cromosoma2[3]*1+cromosoma2[2]*2+cromosoma2[1]*2*2+cromosoma2[0]*2*2*2

    f1 = fitness(x1)
    f2 = fitness(x2)

    print("Fitness -> Individuo 1 (x=", x1, "): ",
          f1, "  Individuo 2 (x=", x2, "): ", f2)

    # Probabilidad de individuos
    prob1 = f1/(f1+f2)
    prob2 = f2/(f1+f2)

    print("Probabilidad -> Individuo 1 (p=", prob1, ")",
          "  Individuo 2 (p=", prob2, ")")

    return f1, f2, x1, x2

# %%
def emparejamiento(k):
    # Individuo 1
    if lista[k] > prob1:
        apto1 = "NO"
    else:
        apto1 = "SI"
    k = k+1

    # Individuo 2
    if lista[k] > prob1:
        apto2 = "SI"
    else:
        apto2 = "NO"
    k = k+1

    # Probabilidad de emparejamiento
    if lista[k] > prob_empar:
        pempar = "NO"
    else:
        pempar = "SI"

    k = k+1

    print("Aptitud para emparejamiento -> Individuo 1: ",
          apto1, "  Individuo 2: ", apto2)

    if (pempar == "SI") and (apto1 == "SI") and (apto2 == "SI"):
        print("Hay emparejamiento en esta generación")
        # Punto de corte
        if lista[k] < 0.33:
            pcorte = 1
        elif lista[k] > 0.33 and lista[k] < 0.66:
            pcorte = 2
        else:
            pcorte = 3
        print("Punto de corte para emparejamiento: ", pcorte)
        # Nuevos individuos
        aux1 = cromosoma1
        aux2 = cromosoma2
        cromosoma1 = aux1[0:pcorte]+aux2[pcorte:Lcrom]
        cromosoma2 = aux2[0:pcorte]+aux1[pcorte:Lcrom]
        print("Nuevos Individuos tras emparejamiento")
        print("Individuo 1 :", cromosoma1)
        print("Individuo 2 :", cromosoma2)
    else:
        print("No hay emparejamiento en esta generación")

    return

# %%
def mutacion(k):
    # Mutación
    # Individuo 1
    j = 0
    for i in range(k, k+Lcrom):
        if lista[i] > prob_mut:
            print("Se produce mutación en el individuo 1 en la posición ", j)
            if cromosoma1[j] == 1:
                cromosoma1[j] = 0
            else:
                cromosoma1[j] = 1
        j = j+1

    k = k+Lcrom

    # Individuo 2
    j = 0
    for i in range(k, k+Lcrom):
        if lista[i] > prob_mut:
            print("Se produce mutación en el individuo 2 en la posición ", j)
            if cromosoma2[j] == 1:
                cromosoma2[j] = 0
            else:
                cromosoma2[j] = 1
        j = j+1

    k = k+Lcrom

    print("Resultado de la mutación")
    print("Individuo 1 :", cromosoma1)
    print("Individuo 2 :", cromosoma2)

    return

# %%
# Inicializar cromosomas
inicializarcromosomas(pos_aleat)
pos_aleat = pos_aleat+2*Lcrom
# Out:
# GENERACIÓN INICIAL
# Individuo 1 : [0, 1, 0, 0]
# Individuo 2 : [1, 1, 0, 1]

# %%
# Aplicar evolución a nuevas generaciones
n_gen = 20
for g in range(0, n_gen):
    print("\nGENERACIÓN ", g)
    f1, f2, x1, x2 = resultadofitness()
    # Emparejamiento
    emparejamiento(pos_aleat)
    pos_aleat = pos_aleat+3
    # Mutación
    mutacion(pos_aleat)
    pos_aleat = pos_aleat+2*Lcrom

    # Máximo fitness
    if (f1 > max_fit):
        max_fit = f1
        max_x = x1
        max_gen = g
    if (f2 > max_fit):
        max_fit = f2
        max_x = x2
        max_gen = g
    print("Máximo de la función: ", max_fit,
          " (x= ", max_x, " Generación: ", max_gen, ")")
# Out:
# GENERACIÓN  0
# Fitness -> Individuo 1 (x= 4 ):  0.8043774188942653   Individuo 2 (x= 13 ):  3.305556962915138
# Probabilidad -> Individuo 1 (p= 0.19571539206427357 )   Individuo 2 (p= 0.8042846079357263 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  2
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [1, 1, 1, 1]
# Individuo 2 : [0, 0, 1, 0]
# Máximo de la función:  3.305556962915138  (x=  13  Generación:  0 )
#
# GENERACIÓN  1
# Fitness -> Individuo 1 (x= 15 ):  3.7731750674323625   Individuo 2 (x= 2 ):  1.03117679627321
# Probabilidad -> Individuo 1 (p= 0.7853660960881687 )   Individuo 2 (p= 0.2146339039118314 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  2
# Resultado de la mutación
# Individuo 1 : [0, 1, 0, 0]
# Individuo 2 : [1, 1, 0, 0]
# Máximo de la función:  3.7731750674323625  (x=  15  Generación:  1 )
#
# GENERACIÓN  2
# Fitness -> Individuo 1 (x= 4 ):  0.8043774188942653   Individuo 2 (x= 12 ):  4.783292646488061
# Probabilidad -> Individuo 1 (p= 0.14395578290809968 )   Individuo 2 (p= 0.8560442170919003 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  2
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [1, 1, 0, 1]
# Individuo 2 : [1, 1, 1, 1]
# Máximo de la función:  4.783292646488061  (x=  12  Generación:  2 )
#
# GENERACIÓN  3
# Fitness -> Individuo 1 (x= 13 ):  3.305556962915138   Individuo 2 (x= 15 ):  3.7731750674323625
# Probabilidad -> Individuo 1 (p= 0.4669702071986564 )   Individuo 2 (p= 0.5330297928013435 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [0, 0, 1, 0]
# Individuo 2 : [1, 0, 1, 0]
# Máximo de la función:  4.783292646488061  (x=  12  Generación:  2 )
#
# GENERACIÓN  4
# Fitness -> Individuo 1 (x= 2 ):  1.03117679627321   Individuo 2 (x= 10 ):  3.434115726124435
# Probabilidad -> Individuo 1 (p= 0.23093152152986343 )   Individuo 2 (p= 0.7690684784701366 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  2
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [1, 1, 0, 1]
# Individuo 2 : [1, 1, 0, 1]
# Máximo de la función:  4.783292646488061  (x=  12  Generación:  2 )
#
# GENERACIÓN  5
# Fitness -> Individuo 1 (x= 13 ):  3.305556962915138   Individuo 2 (x= 13 ):  3.305556962915138
# Probabilidad -> Individuo 1 (p= 0.5 )   Individuo 2 (p= 0.5 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  2
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [0, 0, 0, 0]
# Individuo 2 : [0, 0, 1, 0]
# Máximo de la función:  4.783292646488061  (x=  12  Generación:  2 )
#
# GENERACIÓN  6
# Fitness -> Individuo 1 (x= 0 ):  2.5   Individuo 2 (x= 2 ):  1.03117679627321
# Probabilidad -> Individuo 1 (p= 0.7079792783636577 )   Individuo 2 (p= 0.29202072163634224 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  2
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [1, 1, 1, 0]
# Individuo 2 : [0, 1, 0, 1]
# Máximo de la función:  4.783292646488061  (x=  12  Generación:  2 )
#
# GENERACIÓN  7
# Fitness -> Individuo 1 (x= 14 ):  3.009422143920609   Individuo 2 (x= 5 ):  0.0
# Probabilidad -> Individuo 1 (p= 1.0 )   Individuo 2 (p= 0.0 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [1, 0, 1, 0]
# Individuo 2 : [1, 1, 0, 0]
# Máximo de la función:  4.783292646488061  (x=  12  Generación:  2 )
#
# GENERACIÓN  8
# Fitness -> Individuo 1 (x= 10 ):  3.434115726124435   Individuo 2 (x= 12 ):  4.783292646488061
# Probabilidad -> Individuo 1 (p= 0.4179073949360817 )   Individuo 2 (p= 0.5820926050639182 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  1
# Resultado de la mutación
# Individuo 1 : [0, 1, 1, 1]
# Individuo 2 : [0, 0, 0, 0]
# Máximo de la función:  4.783292646488061  (x=  12  Generación:  2 )
#
# GENERACIÓN  9
# Fitness -> Individuo 1 (x= 7 ):  0.752732437929649   Individuo 2 (x= 0 ):  2.5
# Probabilidad -> Individuo 1 (p= 0.23141541835785304 )   Individuo 2 (p= 0.7685845816421469 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  2
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [1, 0, 0, 0]
# Individuo 2 : [1, 1, 1, 1]
# Máximo de la función:  4.783292646488061  (x=  12  Generación:  2 )
#
# GENERACIÓN  10
# Fitness -> Individuo 1 (x= 8 ):  1.0035598789100098   Individuo 2 (x= 15 ):  3.7731750674323625
# Probabilidad -> Individuo 1 (p= 0.21009327295383065 )   Individuo 2 (p= 0.7899067270461693 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  2
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [0, 0, 1, 1]
# Individuo 2 : [0, 1, 0, 0]
# Máximo de la función:  4.783292646488061  (x=  12  Generación:  2 )
#
# GENERACIÓN  11
# Fitness -> Individuo 1 (x= 3 ):  0.9340905659053925   Individuo 2 (x= 4 ):  0.8043774188942653
# Probabilidad -> Individuo 1 (p= 0.5373067402291206 )   Individuo 2 (p= 0.4626932597708794 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  2
# Resultado de la mutación
# Individuo 1 : [1, 1, 0, 0]
# Individuo 2 : [0, 0, 1, 0]
# Máximo de la función:  4.783292646488061  (x=  12  Generación:  2 )
#
# GENERACIÓN  12
# Fitness -> Individuo 1 (x= 12 ):  4.783292646488061   Individuo 2 (x= 2 ):  1.03117679627321
# Probabilidad -> Individuo 1 (p= 0.8226533295214108 )   Individuo 2 (p= 0.17734667047858932 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [1, 0, 1, 1]
# Individuo 2 : [1, 1, 1, 1]
# Máximo de la función:  4.783292646488061  (x=  12  Generación:  2 )
#
# GENERACIÓN  13
# Fitness -> Individuo 1 (x= 11 ):  5.999941239879686   Individuo 2 (x= 15 ):  3.7731750674323625
# Probabilidad -> Individuo 1 (p= 0.613923036543692 )   Individuo 2 (p= 0.38607696345630815 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [1, 1, 0, 0]
# Individuo 2 : [0, 0, 1, 0]
# Máximo de la función:  5.999941239879686  (x=  11  Generación:  13 )
#
# GENERACIÓN  14
# Fitness -> Individuo 1 (x= 12 ):  4.783292646488061   Individuo 2 (x= 2 ):  1.03117679627321
# Probabilidad -> Individuo 1 (p= 0.8226533295214108 )   Individuo 2 (p= 0.17734667047858932 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  2
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [0, 0, 1, 0]
# Individuo 2 : [1, 1, 0, 1]
# Máximo de la función:  5.999941239879686  (x=  11  Generación:  13 )
#
# GENERACIÓN  15
# Fitness -> Individuo 1 (x= 2 ):  1.03117679627321   Individuo 2 (x= 13 ):  3.305556962915138
# Probabilidad -> Individuo 1 (p= 0.23777728897662426 )   Individuo 2 (p= 0.7622227110233757 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  2
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [1, 1, 1, 1]
# Individuo 2 : [1, 1, 1, 0]
# Máximo de la función:  5.999941239879686  (x=  11  Generación:  13 )
#
# GENERACIÓN  16
# Fitness -> Individuo 1 (x= 15 ):  3.7731750674323625   Individuo 2 (x= 14 ):  3.009422143920609
# Probabilidad -> Individuo 1 (p= 0.5563023941797218 )   Individuo 2 (p= 0.44369760582027823 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  2
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [0, 0, 0, 1]
# Individuo 2 : [0, 0, 0, 1]
# Máximo de la función:  5.999941239879686  (x=  11  Generación:  13 )
#
# GENERACIÓN  17
# Fitness -> Individuo 1 (x= 1 ):  1.4077215714628977   Individuo 2 (x= 1 ):  1.4077215714628977
# Probabilidad -> Individuo 1 (p= 0.5 )   Individuo 2 (p= 0.5 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  2
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [0, 1, 1, 1]
# Individuo 2 : [1, 0, 1, 0]
# Máximo de la función:  5.999941239879686  (x=  11  Generación:  13 )
#
# GENERACIÓN  18
# Fitness -> Individuo 1 (x= 7 ):  0.752732437929649   Individuo 2 (x= 10 ):  3.434115726124435
# Probabilidad -> Individuo 1 (p= 0.17978498584978195 )   Individuo 2 (p= 0.8202150141502181 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  1
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  2
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [0, 0, 1, 1]
# Individuo 2 : [0, 0, 0, 1]
# Máximo de la función:  5.999941239879686  (x=  11  Generación:  13 )
#
# GENERACIÓN  19
# Fitness -> Individuo 1 (x= 3 ):  0.9340905659053925   Individuo 2 (x= 1 ):  1.4077215714628977
# Probabilidad -> Individuo 1 (p= 0.39887510658951325 )   Individuo 2 (p= 0.6011248934104868 )
# Aptitud para emparejamiento -> Individuo 1:  NO   Individuo 2:  SI
# No hay emparejamiento en esta generación
# Se produce mutación en el individuo 1 en la posición  0
# Se produce mutación en el individuo 1 en la posición  2
# Se produce mutación en el individuo 1 en la posición  3
# Se produce mutación en el individuo 2 en la posición  0
# Se produce mutación en el individuo 2 en la posición  1
# Se produce mutación en el individuo 2 en la posición  3
# Resultado de la mutación
# Individuo 1 : [1, 0, 0, 0]
# Individuo 2 : [1, 1, 0, 0]
# Máximo de la función:  5.999941239879686  (x=  11  Generación:  13 )
